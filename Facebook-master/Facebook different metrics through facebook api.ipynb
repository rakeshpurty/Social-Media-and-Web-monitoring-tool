# %%
import json
import requests
import pandas as pd
import re
import time as t
import datetime as dt
from datetime import timedelta

    
start_date=str(dt.datetime.now().date() - timedelta(days=1))
end_date=str(dt.datetime.now().date())

date_time = start_date
pattern = '%Y-%m-%d'
epoch1 = int(t.mktime(t.strptime(date_time, pattern)))

date_time = end_date
pattern = '%Y-%m-%d'
epoch2 = int(t.mktime(t.strptime(date_time, pattern)))


# page_impressions_unique

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_impressions_unique","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a1 = json.loads(response.text)

total_reach_count = []
date_time=[]
dates=[]

for i in range(len(a1['data'][0]['values'])):
    for j in a1['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            total_reach_count.append(tuple(j)[1])
        else:
            date_time.append(tuple(j)[1])

for i in date_time:
    dates.append(i.split('T')[0]) 
    
# page_impressions_organic_unique

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_impressions_organic_unique","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a2 = json.loads(response.text)

organic_reach_count = []
date_time=[]
dates=[]

for i in range(len(a2['data'][0]['values'])):
    for j in a2['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            organic_reach_count.append(tuple(j)[1])
        else:
            date_time.append(tuple(j)[1])

for i in date_time:
    dates.append(i.split('T')[0])

# page_impressions_viral_unique

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_impressions_viral_unique","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a3 = json.loads(response.text)

viral_reach_count = []
date_time=[]
dates=[]

for i in range(len(a3['data'][0]['values'])):
    for j in a3['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            viral_reach_count.append(tuple(j)[1])
        else:
            date_time.append(tuple(j)[1])

for i in date_time:    
    dates.append(i.split('T')[0])

# page_impressions_paid_unique

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_impressions_paid_unique","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a4 = json.loads(response.text)

paid_reach_count = []
date_time=[]
dates=[]

for i in range(len(a4['data'][0]['values'])):
    for j in a4['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            paid_reach_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:    
    dates.append(i.split('T')[0])

# page_impressions

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_impressions","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a5 = json.loads(response.text)

total_impressions_count = [] 
date_time=[]
dates=[]

for i in range(len(a5['data'][0]['values'])):
    for j in a5['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            total_impressions_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:    
    dates.append(i.split('T')[0])

# page_impressions_organic

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_impressions_organic","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a6 = json.loads(response.text)

organic_impressions_count = []
date_time=[]
dates=[]

for i in range(len(a6['data'][0]['values'])):
    for j in a6['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            organic_impressions_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:    
    dates.append(i.split('T')[0]) 

# page_impressions_viral

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_impressions_viral","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a7 = json.loads(response.text)

viral_impressions_count = []
date_time=[]
dates=[]

for i in range(len(a7['data'][0]['values'])):
    for j in a7['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            viral_impressions_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:    
    dates.append(i.split('T')[0]) 

# page_impressions_paid

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_impressions_paid","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
b1 = json.loads(response.text)

paid_impressions_count = []
date_time=[]
dates=[]

for i in range(len(b1['data'][0]['values'])):
    for j in b1['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            paid_impressions_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:    
    dates.append(i.split('T')[0])

# page_posts_impressions_unique

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_posts_impressions_unique","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a8 = json.loads(response.text)

page_posts_impressions_unique_count = []
date_time=[]
dates=[]

for i in range(len(a8['data'][0]['values'])):
    for j in a8['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_posts_impressions_unique_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:    
    dates.append(i.split('T')[0])

# page_posts_impressions_organic_unique

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_posts_impressions_organic_unique","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a9 = json.loads(response.text)

page_posts_impressions_organic_unique_count = []
date_time=[]
dates=[]

for i in range(len(a9['data'][0]['values'])):
    for j in a9['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_posts_impressions_organic_unique_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:    
    dates.append(i.split('T')[0]) 

# page_posts_impressions_viral_unique

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_posts_impressions_viral_unique","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a10 = json.loads(response.text)

page_posts_impressions_viral_unique_count = []
date_time=[]
dates=[]

for i in range(len(a10['data'][0]['values'])):
    for j in a10['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_posts_impressions_viral_unique_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:    
    dates.append(i.split('T')[0]) 

# page_posts_impressions_paid_unique

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_posts_impressions_paid_unique","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a11 = json.loads(response.text)

page_posts_impressions_paid_unique_count = []
date_time=[]
dates=[]

for i in range(len(a11['data'][0]['values'])):
    for j in a11['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_posts_impressions_paid_unique_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:    
    dates.append(i.split('T')[0]) 

# page_posts_impressions

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_posts_impressions","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a12 = json.loads(response.text)

page_posts_impressions_count = []
date_time=[]
dates=[]

for i in range(len(a12['data'][0]['values'])):
    for j in a12['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_posts_impressions_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:    
    dates.append(i.split('T')[0])

# page_posts_impressions_organic

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_posts_impressions_organic","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a13 = json.loads(response.text)

page_posts_impressions_organic_count = []
date_time=[]
dates=[]

for i in range(len(a13['data'][0]['values'])):
    for j in a13['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_posts_impressions_organic_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:    
    dates.append(i.split('T')[0])

# page_posts_impressions_viral

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_posts_impressions_viral","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a14 = json.loads(response.text)

page_posts_impressions_viral_count = []
date_time=[]
dates=[]

for i in range(len(a14['data'][0]['values'])):
    for j in a14['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_posts_impressions_viral_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])
for i in date_time:    
        dates.append(i.split('T')[0]) 
        
# page_posts_impressions_paid

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_posts_impressions_paid","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a15 = json.loads(response.text)

page_posts_impressions_paid_count = []
date_time=[]
dates=[]

for i in range(len(a15['data'][0]['values'])):
    for j in a15['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_posts_impressions_paid_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:    
    dates.append(i.split('T')[0])  

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_views_total","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a16 = json.loads(response.text)

page_views_count = []
date_time=[]
dates=[]

for i in range(len(a16['data'][0]['values'])):
    for j in a16['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_views_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:    
    dates.append(i.split('T')[0])

# page_video_views

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_video_views","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a17 = json.loads(response.text)

page_video_views_count = []
date_time=[]
dates=[]

for i in range(len(a17['data'][0]['values'])):
    for j in a17['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_video_views_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:    
    dates.append(i.split('T')[0])   

# page_video_views_paid

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_video_views_paid","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a18 = json.loads(response.text)

page_video_views_paid_count = []
date_time=[]
dates=[]

for i in range(len(a18['data'][0]['values'])):
    for j in a18['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_video_views_paid_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:    
    dates.append(i.split('T')[0])

# page_video_views_organic

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_video_views_organic","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a19 = json.loads(response.text)

page_video_views_organic_count = []
date_time=[]
dates=[]

for i in range(len(a19['data'][0]['values'])):
    for j in a19['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_video_views_organic_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:    
    dates.append(i.split('T')[0])   
    
# page_video_views_autoplayed

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_video_views_autoplayed","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a20 = json.loads(response.text)

page_video_views_autoplayed_count = []
date_time=[]
dates=[]

for i in range(len(a20['data'][0]['values'])):
    for j in a20['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_video_views_autoplayed_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:    
    dates.append(i.split('T')[0]) 

# page_video_views_click_to_play

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_video_views_click_to_play","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a21 = json.loads(response.text)

page_video_views_click_to_play_count = []
date_time=[]
dates=[]

for i in range(len(a21['data'][0]['values'])):
    for j in a21['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_video_views_click_to_play_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:    
    dates.append(i.split('T')[0]) 

# page_video_views_unique

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_video_views_unique","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a22 = json.loads(response.text)

page_video_views_unique_count = []
date_time=[]
dates=[]

for i in range(len(a22['data'][0]['values'])):
    for j in a22['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_video_views_unique_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:    
    dates.append(i.split('T')[0])

# page_video_repeat_views

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_video_repeat_views","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a23 = json.loads(response.text)

page_video_repeat_views_count = []
date_time=[]
dates=[]

for i in range(len(a23['data'][0]['values'])):
    for j in a23['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_video_repeat_views_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:    
    dates.append(i.split('T')[0])   

# page_video_complete_views_30s

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_video_complete_views_30s","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a24 = json.loads(response.text)

page_video_complete_views_30s_count = []
date_time=[]
dates=[]

for i in range(len(a24['data'][0]['values'])):
    for j in a24['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_video_complete_views_30s_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:    
    dates.append(i.split('T')[0])

# page_video_complete_views_30s_paid

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_video_complete_views_30s_paid","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a25 = json.loads(response.text)

page_video_complete_views_30s_paid_count = []
date_time=[]
dates=[]

for i in range(len(a25['data'][0]['values'])):
    for j in a25['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_video_complete_views_30s_paid_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])
for i in date_time:
    dates.append(i.split('T')[0])

# page_video_complete_views_30s_organic

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_video_complete_views_30s_organic","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a26 = json.loads(response.text)

page_video_complete_views_30s_organic_count = []
date_time=[]
dates=[]

for i in range(len(a26['data'][0]['values'])):
    for j in a26['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_video_complete_views_30s_organic_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:
    dates.append(i.split('T')[0])

# page_video_complete_views_30s_autoplayed

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_video_complete_views_30s_autoplayed","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a27 = json.loads(response.text)

page_video_complete_views_30s_autoplayed_count = []
date_time=[]
dates=[]

for i in range(len(a27['data'][0]['values'])):
    for j in a27['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_video_complete_views_30s_autoplayed_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:
    dates.append(i.split('T')[0])

# page_video_complete_views_30s_click_to_play

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_video_complete_views_30s_click_to_play","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a28 = json.loads(response.text)

page_video_complete_views_30s_click_to_play_count = []
date_time=[]
dates=[]

for i in range(len(a28['data'][0]['values'])):
    for j in a28['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_video_complete_views_30s_click_to_play_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:
    dates.append(i.split('T')[0])    

# page_video_complete_views_30s_unique

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_video_complete_views_30s_unique","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a29 = json.loads(response.text)

page_video_complete_views_30s_unique_count = []
date_time=[]
dates=[]

for i in range(len(a29['data'][0]['values'])):
    for j in a29['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_video_complete_views_30s_unique_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:
    dates.append(i.split('T')[0])  

# page_video_complete_views_30s_repeat_views

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_video_complete_views_30s_repeat_views","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a30 = json.loads(response.text)

page_video_complete_views_30s_repeat_views_count = []
date_time=[]
dates=[]

for i in range(len(a30['data'][0]['values'])):
    for j in a30['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_video_complete_views_30s_repeat_views_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:
    dates.append(i.split('T')[0]) 
    
# page_video_views_10s

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_video_views_10s","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a31 = json.loads(response.text)

page_video_views_10s_count = []
date_time=[]
dates=[]

for i in range(len(a31['data'][0]['values'])):
    for j in a31['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_video_views_10s_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:
    dates.append(i.split('T')[0])

# page_video_views_10s_paid

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_video_views_10s_paid","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a32 = json.loads(response.text)    

page_video_views_10s_paid_count = []
date_time=[]
dates=[]

for i in range(len(a32['data'][0]['values'])):
    for j in a32['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_video_views_10s_paid_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:
    dates.append(i.split('T')[0])
    
# page_video_views_10s_organic

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_video_views_10s_organic","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a33 = json.loads(response.text)

page_video_views_10s_organic_count = []
date_time=[]
dates=[]

for i in range(len(a33['data'][0]['values'])):
    for j in a33['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_video_views_10s_organic_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:
    dates.append(i.split('T')[0]) 

# page_video_views_10s_autoplayed

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_video_views_10s_autoplayed","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a34 = json.loads(response.text)

page_video_views_10s_autoplayed_count = []
date_time=[]
dates=[]

for i in range(len(a34['data'][0]['values'])):
    for j in a34['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_video_views_10s_autoplayed_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:
    dates.append(i.split('T')[0])

# page_video_views_10s_click_to_play

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_video_views_10s_click_to_play","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a35 = json.loads(response.text)

page_video_views_10s_click_to_play_count = []
date_time=[]
dates=[]

for i in range(len(a35['data'][0]['values'])):
    for j in a35['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_video_views_10s_click_to_play_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:
    dates.append(i.split('T')[0]) 

# page_video_views_10s_unique

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_video_views_10s_unique","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a36 = json.loads(response.text)

page_video_views_10s_unique_count = []
date_time=[]
dates=[]

for i in range(len(a36['data'][0]['values'])):
    for j in a36['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_video_views_10s_unique_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:
    dates.append(i.split('T')[0]) 

# page_video_views_10s_repeat

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_video_views_10s_repeat","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a37 = json.loads(response.text)

page_video_views_10s_repeat_count = []
date_time=[]
dates=[]

for i in range(len(a37['data'][0]['values'])):
    for j in a37['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_video_views_10s_repeat_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:
    dates.append(i.split('T')[0]) 

# page_video_view_time

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_video_view_time","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a38 = json.loads(response.text)

page_video_view_time_count = []
date_time=[]
dates=[]

for i in range(len(a38['data'][0]['values'])):
    for j in a38['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_video_view_time_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:
    dates.append(i.split('T')[0]) 

# page_fan

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_fans","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a39 = json.loads(response.text)

lifetime_total_likes_count = []
date_time=[]
dates=[]

for i in range(len(a39['data'][0]['values'])):
    for j in a39['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
             lifetime_total_likes_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:
    dates.append(i.split('T')[0]) 

# page_fan_adds

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_fan_adds","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a40 = json.loads(response.text)

new_likes_count = []
date_time=[]
dates=[]

for i in range(len(a40['data'][0]['values'])):
    for j in a40['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
             new_likes_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:
    dates.append(i.split('T')[0]) 

# page_fan_removes

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_fan_removes","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a41 = json.loads(response.text)

unlikes_count = []
date_time=[]
dates=[]

for i in range(len(a41['data'][0]['values'])):
    for j in a41['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            unlikes_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:
    dates.append(i.split('T')[0])  

# page_engaged_users

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_engaged_users","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a42 = json.loads(response.text)

page_engaged_users_count = []
date_time=[]
dates=[]

for i in range(len(a42['data'][0]['values'])):
    for j in a42['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_engaged_users_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:
    dates.append(i.split('T')[0])  
    
# page_consumptions

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_consumptions","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a43 = json.loads(response.text)

page_consumptions_count = []
date_time=[]
dates=[]

for i in range(len(a43['data'][0]['values'])):
    for j in a43['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_consumptions_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:
    dates.append(i.split('T')[0])

# page_consumptions_unique

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_consumptions_unique","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a44 = json.loads(response.text)

page_consumers_count = []
date_time=[]
dates=[]

for i in range(len(a44['data'][0]['values'])):
    for j in a44['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_consumers_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:
    dates.append(i.split('T')[0])

# page_negative_feedback

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_negative_feedback","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring) 
a45 = json.loads(response.text)

page_negative_feedback_count = []
date_time=[]
dates=[]

for i in range(len(a45['data'][0]['values'])):
    for j in a45['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_negative_feedback_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:
    dates.append(i.split('T')[0]) 

# page_negative_feedback_unique

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_negative_feedback_unique","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a46 = json.loads(response.text)

page_negative_feedback_unique_count = []
date_time=[]
dates=[]

for i in range(len(a46['data'][0]['values'])):
    for j in a46['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_negative_feedback_unique_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:
    dates.append(i.split('T')[0]) 
    
# page_total_actions

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_total_actions","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a47 = json.loads(response.text)

page_total_actions_count = []
date_time=[]
dates=[]

for i in range(len(a47['data'][0]['values'])):
    for j in a47['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_total_actions_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:
    dates.append(i.split('T')[0]) 

# page_website_clicks_logged_in_unique

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_website_clicks_logged_in_unique","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a48 = json.loads(response.text)

page_website_clicks_logged_in_unique_count = []
date_time=[]
dates=[]

for i in range(len(a48['data'][0]['values'])):
    for j in a48['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
            page_website_clicks_logged_in_unique_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:
    dates.append(i.split('T')[0]) 

dailyupdates = pd.DataFrame({'dates':dates,'total_reach_count':total_reach_count,'dates':dates,' organic_reach_count': organic_reach_count,'dates':dates,'viral_reach_count':viral_reach_count,'dates':dates,'paid_reach_count':paid_reach_count,'dates':dates,'total_impressions_count':total_impressions_count,'dates':dates,' organic_impressions_count': organic_impressions_count,'dates':dates,'viral_impressions_count':viral_impressions_count,'dates':dates,'paid_impressions_count':paid_impressions_count,'dates':dates,'total_reach_count':total_reach_count,'dates':dates,' organic_reach_count': organic_reach_count,'dates':dates,'viral_reach_count':viral_reach_count,'dates':dates,'paid_reach_count':paid_reach_count,'dates':dates,'total_impressions_count':total_impressions_count,'dates':dates,' organic_impressions_count': organic_impressions_count,'dates':dates,'viral_impressions_count':viral_impressions_count,'dates':dates,'paid_impressions_count':paid_impressions_count,'dates':dates,'page_posts_impressions_unique_count':page_posts_impressions_unique_count,'dates':dates,'page_posts_impressions_organic_unique_count':page_posts_impressions_organic_unique_count,'dates':dates,'page_posts_impressions_viral_unique_count':page_posts_impressions_viral_unique_count,'dates':dates,'page_posts_impressions_paid_unique_count':page_posts_impressions_paid_unique_count,'dates':dates,'page_posts_impressions_count':page_posts_impressions_count,'dates':dates,'page_posts_impressions_organic_count':page_posts_impressions_organic_count,'dates':dates,'page_posts_impressions_viral_count':page_posts_impressions_viral_count,'dates':dates,'page_posts_impressions_paid_count':page_posts_impressions_paid_count,'dates':dates,'lifetime_total_likes_count':lifetime_total_likes_count,'dates':dates,'new_likes_count':new_likes_count,'dates':dates,'unlikes_count':unlikes_count,'dates':dates,'page_engaged_users_count':page_engaged_users_count,'dates':dates,'page_consumptions_count':page_consumptions_count,'dates':dates,'page_consumers_count':page_consumers_count,'dates':dates,'page_negative_feedback_count':page_negative_feedback_count,'dates':dates,'page_negative_feedback_unique_count':page_negative_feedback_unique_count,'dates':dates,'page_total_actions_count':page_total_actions_count,'dates':dates,'page_website_clicks_logged_in_unique_count':page_website_clicks_logged_in_unique_count,'dates':dates,'page_video_complete_views_30s_count':page_video_complete_views_30s_count,'dates':dates,'page_video_complete_views_30s_paid_count':page_video_complete_views_30s_paid_count,'dates':dates,'page_video_complete_views_30s_organic_count':page_video_complete_views_30s_organic_count,'dates':dates,'page_video_complete_views_30s_autoplayed_count':page_video_complete_views_30s_autoplayed_count,'dates':dates,'page_video_complete_views_30s_click_to_play_count':page_video_complete_views_30s_click_to_play_count,'dates':dates,'page_video_complete_views_30s_unique_count':page_video_complete_views_30s_unique_count,'dates':dates,'page_video_complete_views_30s_repeat_views_count':page_video_complete_views_30s_repeat_views_count,'dates':dates,'page_views_count':page_views_count,'dates':dates,'page_video_views_count':page_video_views_count,'dates':dates,'page_video_views_paid_count':page_video_views_paid_count,'dates':dates,'page_video_views_organic_count':page_video_views_organic_count,'dates':dates,'page_video_views_autoplayed_count':page_video_views_autoplayed_count,'dates':dates,'page_video_views_click_to_play_count':page_video_views_click_to_play_count,'dates':dates,'page_video_views_unique_count':page_video_views_unique_count,'dates':dates,'page_video_repeat_views_count':page_video_repeat_views_count,'dates':dates,'page_video_views_10s_count':page_video_views_10s_count,'dates':dates,'page_video_views_10s_paid_count':page_video_views_10s_paid_count,'dates':dates,' page_video_views_10s_organic_count': page_video_views_10s_organic_count,'dates':dates,'page_video_views_10s_autoplayed_count':page_video_views_10s_autoplayed_count,'dates':dates,'page_video_views_10s_click_to_play_count':page_video_views_10s_click_to_play_count,'dates':dates,'page_video_views_10s_unique_count':page_video_views_10s_unique_count,'dates':dates,'page_video_views_10s_repeat_count':page_video_views_10s_repeat_count,'dates':dates,'page_video_view_time_count':page_video_view_time_count})
daily_updates=dailyupdates.to_csv(index=False)


url = "https://graph.facebook.com/v4.0/{}"

querystring = {"fields":"posts.limit(150)","access_token":access_token}

payload = ""
headers = {
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, data=payload, headers=headers, params=querystring)
data_post = json.loads(response.text)

post_id=[]

for j in range(len(data_post['posts']['data'])):
    for i,k in data_post['posts']['data'][j].items():
          if i == 'id':
                post_id.append(k)

post = []
e=0
while e<len(post_id):

    url = "https://graph.facebook.com/v4.0/"+post_id[e]+""

    querystring = {"fields":"created_time,message,full_picture,likes.summary(true),comments.summary(true),shares.summary(true)","access_token":access_token}

    payload = ""
    headers = {
        'cache-control': "no-cache"
        }

    response = requests.request("GET", url, data=payload, headers=headers, params=querystring)
    post.append(json.loads(response.text))
    e+=1

post_reach = []

a=0
while a<len(post_id):

    url = "https://graph.facebook.com/v4.0/"+post_id[a]+"/insights/"

    querystring = {"metric":"['post_impressions_unique']","access_token":access_token}

    payload = ""
    headers = {
        'cache-control': "no-cache"
        }

    response = requests.request("GET", url, data=payload, headers=headers, params=querystring)


    post_reach.append(json.loads(response.text))
    a+=1

react=0
post_reactions=[]
while react<len(post_id):
    url = "https://graph.facebook.com/v4.0/"+post_id[react]+"/insights/"

    querystring = {"metric":"['post_reactions_by_type_total']","access_token":access_token}

    payload = ""
    headers = {
        'cache-control': "no-cache"
        }

    response = requests.request("GET", url, data=payload, headers=headers, params=querystring)
    post_reactions.append(json.loads(response.text))
    react+=1    

reactions=[]
for o in range(len(post_reactions)):
        for p,n in post_reactions[o]['data'][0]['values'][0].items():
            if p == 'value': 
                reactions.append(n)

reactions_post=pd.DataFrame(reactions).fillna(0)

likes = []
comments = []
shares=[]
message=[]
created_time=[]
dates=[]
reach=[]

for f in range(len(post)):
    for i,j in post[f]['likes']['summary'].items():
        if i == 'total_count':
            likes.append(j)
for x in range(len(post)):
    for k,l in post[x]['comments']['summary'].items():
        if k == 'total_count':
            comments.append(l)

for a in post:
    if "shares" in a:
        shares.append(a["shares"]["count"])
    else:
        shares.append(0)

# shares=[a['shares']['count'] if 'shares' in a else pd.np.null for a in post]

message = [i['message'] if 'message' in i else pd.np.NaN for i in post]
for c in range(len(post)):
    for e,f in post[c].items():
        if e== 'created_time':
            created_time.append(f)
for d in created_time:
    dates.append(d.split('T')[0])

for o in range(len(post_reach)):
    for p,n in post_reach[o]['data'][0]['values'][0].items():
        if p == 'value': 
            reach.append(n)

post_comm = []
e=0
while e<len(post_id):
    url = "https://graph.facebook.com/"+post_id[e]+"/comments"

    querystring = {"summary":"1","filter":"stream","access_token":"EAAIH79MZALrMBAM5xA9zst910gCSG3Ao6daZAM1nHrVNtJwXWsveMZAoywElVTQ1jEkpgZAGa0ep8FttJwllpZBcnZA7reGsgwm7Ey1F2V1cFv8VOuz7dMnLyXKmiCaccIHUKY7ZA3tBjmRZCe0svgBM4mKZBSJno6PpldneqONL1vNN1nX16J3qTz3wsT6u3cT0ZD%0A"}

    headers = {
        'User-Agent': "PostmanRuntime/7.20.1",
        'Accept': "*/*",
        'Cache-Control': "no-cache",
        'Host': "graph.facebook.com",
        'Accept-Encoding': "gzip, deflate",
        'Connection': "keep-alive",
        'cache-control': "no-cache"
        }

    response = requests.request("GET", url, headers=headers, params=querystring)
    post_comm.append(json.loads(response.text))
    e+=1

post_comments=[]
for i in range(len(post_comm)):
    for p,n in post_comm[i]['summary'].items():
        if p == 'total_count': 
            post_comments.append(n)

valdf = pd.DataFrame({'post_id':post_id,'message':message,'dates':dates,'likes':likes,'post_comments':post_comments,'shares':shares,'reach':reach})
valdf['message'] = valdf['message'].str.replace('[^\w\s\n#@/:%.,_-]', '', flags=re.UNICODE)
valdf['message'] = valdf['message'].astype(str)
valdf['message']= valdf['message'].apply(lambda x:x.replace("\n"," ")) 
valdf['message']=valdf.message.apply(lambda x:x.replace(","," "))
valdf['message'] = valdf.message.apply(lambda x:x.strip())

frames = [valdf,reactions_post]

result = pd.concat(frames)
post=pd.concat(frames, axis=1, ignore_index=False,sort=False).reset_index()
post.rename({"like": "post_likes"}, axis=1, inplace=True) 
new_1=post.to_csv(index=False)



url = "https://graph.facebook.com/v4.0/{}"

querystring = {"fields":"videos.limit(100)","access_token":access_token}

payload = ""
headers = {
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, data=payload, headers=headers, params=querystring)

data_video = json.loads(response.text)

video_id=[]

for j in range(len(data_video['videos']['data'])):
    for i,k in data_video['videos']['data'][j].items():
          if i == 'id':
                video_id.append(k)

video = []

e=0
while e<len(video_id):

    url = "https://graph.facebook.com/v4.0/{}_"+video_id[e]+""


    querystring = {"fields":"updated_time,message,full_picture,likes.summary(true),comments.summary(true),shares.summary(true)","access_token":access_token}

    payload = ""
    headers = {
        'cache-control': "no-cache"
        }

    response = requests.request("GET", url, data=payload, headers=headers, params=querystring)

    video.append(json.loads(response.text))
    e+=1

likes = []
comments = []
shares = []
message = []
created_time=[]
dates=[]

for f in range(len(video)):
    for i,j in video[f]['likes']['summary'].items():
        if i == 'total_count':
            likes.append(j)
for x in range(len(video)):
    for k,l in video[x]['comments']['summary'].items():
        if k == 'total_count':
            comments.append(l)
for a in video:
    if "shares" in a:
        shares.append(a["shares"]["count"])
    else:
        shares.append(0)
message = [i['message'] if 'message' in i else pd.np.NaN for i in video]

for c in range(len(video)):
    for e,f in video[c].items():
        if e== 'updated_time':
            created_time.append(f)
for d in created_time:
        dates.append(d.split('T')[0])

video_reach = []

x=0
while x<len(video_id):

    url = "https://graph.facebook.com/v4.0/{}_"+video_id[x]+"/insights/"

    querystring = {"metric":"['post_impressions_unique']","access_token":access_token}

    payload = ""
    headers = {
        'cache-control': "no-cache"
        }

    response = requests.request("GET", url, data=payload, headers=headers, params=querystring)


    video_reach.append(json.loads(response.text))
    x+=1

reach=[]

for o in range(len(video_reach)):
    for p,n in video_reach[o]['data'][0]['values'][0].items():
        if p == 'value': 
            reach.append(n)

video_3s_views = []

a=0
while a<len(video_id):
    url = "https://graph.facebook.com/v4.0/"+video_id[a]+"/video_insights/total_video_views/lifetime"

    querystring = {"access_token":access_token,"":""}

    payload = ""
    headers = {
        'cache-control': "no-cache"
        }

    response = requests.request("GET", url, data=payload, headers=headers, params=querystring)

    video_3s_views.append(json.loads(response.text))
    a+=1

three_second_video_view=[]
for i in range(len(video_3s_views)):
        for j,k in video_3s_views[i]['data'][0]['values'][0].items():
            if j == 'value':
                three_second_video_view.append(k)

video_1min_views = []

b=0
while b<len(video_id):

    url = "https://graph.facebook.com/v4.0/"+video_id[b]+"/video_insights/video_asset_60s_video_view_total_count_by_is_monetizable/lifetime"

    querystring = {"access_token":access_token,"":""}

    payload = ""
    headers = {
        'cache-control': "no-cache"
        }

    response = requests.request("GET", url, data=payload, headers=headers, params=querystring)
    video_1min_views.append(json.loads(response.text))
    b+=1

one_minute_video_view=[]
xyz=[]
for i in range(len(video_1min_views)):   
      for j in video_1min_views[i]['data'][0]['values']:
            xyz.append(list(list(j.values())[0].values()))

for i in xyz:
    if i==[]:
        one_minute_video_view.append(0)
    else:
        one_minute_video_view.append(i[0])

video_10sec_views = []

c=0
while c<len(video_id):
    url = "https://graph.facebook.com/v4.0/"+video_id[c]+"/video_insights/total_video_10s_views/lifetime"

    querystring = {"access_token":access_token,"":""}

    payload = ""
    headers = {
        'cache-control': "no-cache"
        }

    response = requests.request("GET", url, data=payload, headers=headers, params=querystring)
    video_10sec_views.append(json.loads(response.text))
    c+=1

ten_second_video_view=[]
for i in range(len(video_10sec_views)):
        for j,k in video_10sec_views[i]['data'][0]['values'][0].items():
            if j == 'value':
                ten_second_video_view.append(k)

v=0
video_reach=[]
while v<len(video_id):
    url = "https://graph.facebook.com/v4.0/{}_"+video_id[v]+"/insights/"

    querystring = {"metric":"['post_reactions_by_type_total']","access_token":access_token}

    payload = ""
    headers = {
        'cache-control': "no-cache"
        }

    response = requests.request("GET", url, data=payload, headers=headers, params=querystring)
    video_reach.append(json.loads(response.text))
    v+=1

reactions=[]
for o in range(len(video_reach)):
        for p,n in video_reach[o]['data'][0]['values'][0].items():
            if p == 'value': 
                reactions.append(n)

reactions_video=pd.DataFrame(reactions).fillna(0)

video_comm = []
e=0
while e<len(video_id):
    url = "https://graph.facebook.com/"+video_id[e]+"/comments"

    querystring = {"summary":"1","filter":"stream","access_token":"EAAIH79MZALrMBAM5xA9zst910gCSG3Ao6daZAM1nHrVNtJwXWsveMZAoywElVTQ1jEkpgZAGa0ep8FttJwllpZBcnZA7reGsgwm7Ey1F2V1cFv8VOuz7dMnLyXKmiCaccIHUKY7ZA3tBjmRZCe0svgBM4mKZBSJno6PpldneqONL1vNN1nX16J3qTz3wsT6u3cT0ZD%0A"}

    headers = {
        'User-Agent': "PostmanRuntime/7.20.1",
        'Accept': "*/*",
        'Cache-Control': "no-cache",
        'Host': "graph.facebook.com",
        'Accept-Encoding': "gzip, deflate",
        'Connection': "keep-alive",
        'cache-control': "no-cache"
        }

    response = requests.request("GET", url, headers=headers, params=querystring)
    video_comm.append(json.loads(response.text))
    e+=1

video_comments=[]
for i in range(len(video_comm)):
    for p,n in video_comm[i]['summary'].items():
        if p == 'total_count': 
            video_comments.append(n)


valdf1 = pd.DataFrame({'video_id':video_id,'message':message,'dates':dates,'likes':likes,'video_comments':video_comments,'shares':shares,'reach':reach,'three_second_video_view':three_second_video_view,'one_minute_video_view':one_minute_video_view,'ten_second_video_view':ten_second_video_view})
valdf1['message'] = valdf1['message'].str.replace('[^\w\s\n#@/:%.,_-]', '', flags=re.UNICODE)
valdf1['message'] = valdf1['message'].astype(str)
valdf1['message']= valdf1['message'].apply(lambda x:x.replace("\n"," ")) 
valdf1['message']=valdf1.message.apply(lambda x:x.replace(","," "))
valdf1['message'] = valdf1.message.apply(lambda x:x.strip())

frames = [valdf1,reactions_video]

result = pd.concat(frames)
video=pd.concat(frames, axis=1, ignore_index=False,sort=False).reset_index()
video.rename({"like": "post_likes"}, axis=1, inplace=True) 
new_2=video.to_csv(index=False)

# page_fans

url = "https://graph.facebook.com/v4.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_fans","period":"day","since":epoch1,"until":epoch2}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
home = json.loads(response.text)

total_likes_count = []
date_time=[]
dates=[]

for i in range(len(home['data'][0]['values'])):
    for j in home['data'][0]['values'][i].items():
        if tuple(j)[0] == 'value': 
             total_likes_count.append(tuple(j)[1])    
        else:
            date_time.append(tuple(j)[1])

for i in date_time:
    dates.append(i.split('T')[0]) 

home_like=pd.DataFrame({'dates':dates,'total_likes_count':total_likes_count})    
home_likes_fb=home_like.to_csv(index=False)

start_date_fb=str(dt.datetime.now().date() - timedelta(days=7))
end_date_fb=str(dt.datetime.now().date() - timedelta(days=6))

date_time = start_date_fb
pattern = '%Y-%m-%d'
epoch1_fb = int(t.mktime(t.strptime(date_time, pattern)))

date_time = end_date_fb
pattern = '%Y-%m-%d'
epoch2_fb = int(t.mktime(t.strptime(date_time, pattern)))

# page_fans_country

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_fans_country","period":"day","since":epoch1_fb,"until":epoch2_fb}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
x2 = json.loads(response.text)

country=[]
likes=[]
date_time=[]
dates=[]
for i in range(len(x2['data'][0]['values'])):
    for j,k in x2['data'][0]['values'][i]['value'].items():
        country.append(j)
        likes.append(k)
        for l,m in x2['data'][0]['values'][i].items():
            if l == 'end_time':
                date_time.append(m)

for i in date_time:
    dates.append(i.split('T')[0]) 

daily_like_country=pd.DataFrame({'dates':dates,'country':country,'likes':likes})    
daily_likes_country=daily_like_country.to_csv(index=False)

# page_fans_gender_age

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_fans_gender_age","period":"day","since":epoch1_fb,"until":epoch2_fb}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
x3 = json.loads(response.text)

gender_age = []
gender =[]
age =[]
likes = []
date_time = []
dates=[]
for i in range(len(x3['data'][0]['values'])):
    for j,k in x3['data'][0]['values'][i]['value'].items():
        gender_age.append(j)
        likes.append(k)
        for l,m in x3['data'][0]['values'][i].items():
            if l == 'end_time':
                date_time.append(m)

for i in gender_age:
    gender.append(i.split('.')[0])
    age.append(i.split('.')[1])
for i in date_time:
    dates.append(i.split('T')[0]) 

daily_like_gender_age=pd.DataFrame({'dates':dates,'gender':gender,'age':age,'likes':likes})    
daily_likes_gender_age=daily_like_gender_age.to_csv(index=False)

# page_fans_online

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_fans_online","period":"day","since":epoch1_fb,"until":epoch2_fb}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a3_fan = json.loads(response.text)

time = []
active_fans = []
dates = []
for i in range(len(a3_fan['data'][0]['values'])):
    for j,k in a3_fan['data'][0]['values'][i]['value'].items():
        time.append(j)
        active_fans.append(k)
        for j,k in a3_fan['data'][0]['values'][i].items():
            if j =='end_time':
                dates.append(k)
fans_active = pd.DataFrame({'time':time,'active_fans':active_fans,'dates':dates})
fans_active['time']=fans_active['time'].astype(int)
fans_active.sort_values(by=['dates','time'],inplace=True)

l=[]
for i in fans_active['time']:
    if i > 12:
        l.append(str(i-12) +"pm")
    elif i == 0:
        l.append("12am")
    elif i == 12:
        l.append(str(i) + "pm")
    else:
        l.append(str(i)+"am")

fans_active['time'] = l
date = []
for i in fans_active['dates']:
    date.append(i.split("T")[0])
fans_active['dates'] = date
fans_active['dates'] = pd.to_datetime(fans_active['dates'])
fans_active['day_of_week'] = fans_active['dates'].dt.day_name()

new_dicfan = fans_active.to_csv(index=False)

# page_fans_online_per_day

url = "https://graph.facebook.com/v5.0/{}/insights".format(page_id)

querystring = {"access_token":access_token,"metric":"page_fans_online_per_day","period":"day","since":epoch1_fb,"until":epoch2_fb}

headers = {
    'User-Agent': "PostmanRuntime/7.20.1",
    'Accept': "*/*",
    'Cache-Control': "no-cache",
    'Host': "graph.facebook.com",
    'Accept-Encoding': "gzip, deflate",
    'Connection': "keep-alive",
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
a4_fan = json.loads(response.text)

date_time = []
active_fans = []

for i in range(len(a4_fan['data'][0]['values'])):
        for j in a4_fan['data'][0]['values'][i].items():
            if tuple(j)[0] == 'value': 
                active_fans.append(tuple(j)[1])
            else:
                date_time.append(tuple(j)[1])

fans_active = pd.DataFrame({'active_fans':active_fans,'date_time':date_time})

date = []
for i in fans_active['date_time']:
    date.append(i.split("T")[0])
fans_active['date_time'] = date
fans_active['date_time'] = pd.to_datetime(fans_active['date_time'])
fans_active['day_of_week'] = fans_active['date_time'].dt.day_name()

dicfan = fans_active.to_csv(index=False)
# Out:
#   File "<ipython-input-1-b127f2a982d6>", line 99
#     'Accept-Encoding': "gzip, deflate",
#                     ^
# SyntaxError: invalid syntax
